# %%
import pandas as pd
import numpy as np
import jieba
import jieba.posseg as pseg
from string import punctuation as p
from collections import defaultdict
import operator
import re
import jieba.analyse
jieba.analyse.set_stop_words('stopwords.txt')

# %%
replace_numbers = re.compile(r'\d+', re.IGNORECASE)

def re_word(text):
    text = text.lower()
    
    # remove http URL
    text = re.sub(r"https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{2,256}\.[a-z]{2,6}\b([-a-zA-Z0-9@:%_\+.~#?&//=]*)", "", text)
    text = re.sub(r"登陆", "登录", text)
    text = re.sub(r"原件", "组件", text)
    text = re.sub(r"新人", "新员工", text)
    text = re.sub(r"变更", "变动", text)
    text = re.sub(r" +", "", text)
    text = replace_numbers.sub('', text)
    
    return text

# %%
jieba.add_word('关联关系', tag='n')
jieba.add_word('工单', tag='n')
jieba.suggest_freq(('亲', '工'), True)
jieba.add_word('云平台', tag='n')
jieba.add_word('全速云', tag='n')
jieba.add_word('云cas', tag='eng')
jieba.add_word('子菜单', tag='n')
jieba.suggest_freq(('对', '子'), True)
jieba.add_word('外网', tag='n')
jieba.add_word('内网', tag='n')
jieba.add_word('功能码', tag='n')
jieba.add_word('线上', tag='a')
jieba.add_word('清楚点', tag='a')
jieba.add_word('一级菜单', tag='n')
jieba.add_word('某一步', tag='m')
jieba.add_word('下一步', tag='m')
jieba.add_word('入职', tag='v')
jieba.add_word('找你', tag='v')
jieba.add_word('找谁', tag='v')
jieba.add_word('找不到', tag='v')
jieba.add_word('通用岗位', tag='v')
jieba.add_word('走流程', tag='v')
jieba.add_word('登录不了', tag='v')
jieba.add_word('被锁', tag='v')
jieba.add_word('没反应', tag='v')
jieba.add_word('挂了', tag='v')
jieba.add_word('登录不上', tag='v')
jieba.add_word('不存在', tag='v')
jieba.add_word('新员工', tag='n')
jieba.add_word('新用户', tag='n')
jieba.add_word('新组件', tag='n')
jieba.add_word('菜单名', tag='n')
jieba.add_word('用户名', tag='n')
jieba.add_word('岗位变动', tag='n')
jieba.add_word('人事变动', tag='n')
jieba.add_word('dns解析', tag='n')
jieba.add_word('wiki地址', tag='n')

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#           official            additional
# 0  请问员工转岗，该怎么申请权限？       请问员工轮岗，该怎么申请权限？
# 1  请问员工转岗，该怎么申请权限？  我转到别的部门了，怎么添加新部门的权限？
# 2  请问员工转岗，该怎么申请权限？         转岗了，要怎么开通岗位权限
# 3  请问员工转岗，该怎么申请权限？   你好，我转到运维部了，请问怎么申请权限
# 4  请问员工转岗，该怎么申请权限？         岗位变动，权限需要怎么申请

# %%
official = df['official'].values
additional = df['additional'].values

# %%
def seg_and_tag(arr):
    sentence_with_tag = []
    for line in arr:
        temp_list = []
        stop_p = p + "~·！@#￥%……&*（）——=+-{}【】：；“”‘’《》，。？、|、"
        line = re_word(line)
        line = "".join([c for c in line if c not in stop_p])
        words = pseg.cut(line)
        for word, flag in words:
            temp_list.append("{}/{}".format(word, flag))
        sentence_with_tag.append(" ".join(temp_list))
    return sentence_with_tag

# %%
off_list, add_list = seg_and_tag(official), seg_and_tag(additional)

out = np.concatenate([np.expand_dims(off_list, axis=1), np.expand_dims(add_list, axis=1)], axis=1)
dataframe = pd.DataFrame(out, columns=['official', 'additional'])
dataframe.to_csv('train_original.csv', index=False)

print('Done!')
# Out:
# Done!

# %%
with open('statistic_original.txt', 'w', encoding='utf-8') as f:
    for line in (off_list + add_list):
        f.write(line + '\n')
        f.flush()
print('Done!')
# Out:
# Done!

# %% [markdown]
# # Statistic

# %%
with open('statistic_original.txt', 'r', encoding='utf-8') as f:
    dic = defaultdict(int)
    for line in f:
        line = line.strip('\n')
        for word in line.split():
            _, flag = word.split('/')
            dic['/'+flag] += 1
print('Finishe counted!')

# %%
count = 0
for key in dic.keys():
    count += 1
print("total_tags : {}".format(count))
for tag, count in dic.items():
    print("{}\t{}".format(tag, count))

# %% [markdown]
# ## Remove stopwords

# %%
stop_words = open('stopwords.txt', 'r', encoding='utf-8')

# %%
stops = []
for line in stop_words:
    stops.append("".join(line.split()))

# %%
w_file = open('statistic_original_without_stopwords.txt', 'w', encoding='utf-8')

# %%
with open('statistic_original.txt', 'r', encoding='utf-8') as f:
    dic = defaultdict(int)
    for line in f:
        line = line.strip('\n')
        write_list = []
        for word in line.split():
            word, flag = word.split('/')
            if word not in stops:
                dic['/'+flag] += 1
                write_list.append("{}/{}".format(word, flag))
            else:
                write_list.append(word)
        w_file.write(" ".join(write_list) + '\n')
print('Finishe counted!')
# Out:
# Finishe counted!

# %%
count = 0
for key in dic.keys():
    count += 1
print("total_tags : {}".format(count))
for tag, count in dic.items():
    print("{}\t{}".format(tag, count))
w_file.close()
# Out:
# total_tags : 14
# /n	1334
# /v	1007
# /vn	52
# /eng	533
# /ns	34
# /b	20
# /a	34
# /m	25
# /d	8
# /f	12
# /nr	12
# /c	1
# /l	2
# /t	1

# %%
keys = [key for key in dic.keys() if dic[key] > 2]

# %%
keys
# Out:
# ['/n', '/v', '/vn', '/eng', '/ns', '/b', '/a', '/m', '/d', '/f', '/nr']

# %% [markdown]
# ## Write down the tags

# %%
for tag in keys:
    name = tag.split('/')[1]
    w_file = open('tags/tag-{}.txt'.format(name), 'w', encoding='utf-8')
    w_file.write(tag + '\n\n')
    dictionary = defaultdict(int)
    with open('statistic_original_without_stopwords.txt', 'r', encoding='utf-8') as f:
        for line in f:
            words = line.strip('\n').split()
            for word in words:
                if tag in word:
                    temp_word = word.split('/')[0]
                    dictionary[temp_word] += 1
    sorted_dict = sorted(dictionary.items(), key=operator.itemgetter(1), reverse=True)
    for k, v in sorted_dict:
        if tag != '/eng':
            if v > 1:
                w_file.write("{}\t{}\n".format(k, v))
        else:
            w_file.write("{}\t{}\n".format(k, v))
print('Done!')
# Out:
# Done!

# %%
tags=['a','b','d','eng','f','m','n','nr','ns','v','vn']

# %% [markdown]
# # Keyword (Components) extraction

# %%
total_sentences = np.concatenate([official, additional], axis=0)
key_word_each_sent = []
for line in total_sentences:
    keywords = jieba.analyse.extract_tags(line, topK=5, allowPOS=tags)
    key_word_each_sent.append(keywords)
    
print('Done!')
# Out:
# Done!

# %%
key_word_each_sent
# Out:
# [['转岗', '权限', '员工', '申请'],
#  ['转岗', '权限', '员工', '申请'],
#  ['转岗', '权限', '员工', '申请'],
#  ['转岗', '权限', '员工', '申请'],
#  ['转岗', '权限', '员工', '申请'],
#  ['岗位', '流程', '变更', '新增', '已有'],
#  ['岗位', '流程', '变更', '新增', '已有'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['RMP', '组件', '权限', '流程', '申请'],
#  ['wsms', '组件', '权限', '流程', '申请'],
#  ['gdui', 'business', '流程', '角色', '申请'],
#  ['SI', '权限', '流程', '申请'],
#  ['SI', '权限', '流程', '申请'],
#  ['SI', '权限', '流程', '申请'],
#  ['SI', '权限', '流程', '申请'],
#  ['Portal', '账号', '关联', '角色', '申请'],
#  ['岗位', '角色', '申请', '部门', '不能'],
#  ['Portal', '账号', '权限', '同事', '开通'],
#  ['Portal', '账号', '权限', '同事', '开通'],
#  ['Portal', '账号', '权限', '同事', '开通'],
#  [],
#  [],
#  ['管理员', '组件', '查询', '姓名', '协助'],
#  ['管理员', '组件', '查询', '姓名', '协助'],
#  ['管理员', '组件', '查询', '姓名', '协助'],
#  ['组件', '查询', '岗位', '协助', '管理'],
#  ['组件', '查询', '岗位', '协助', '管理'],
#  ['查询', '权限', '岗位', '协助', '角色'],
#  ['查询', '权限', '岗位', '协助', '角色'],
#  ['查询', '权限', '岗位', '协助', '角色'],
#  ['组件', '权限', '岗位', '告知'],
#  ['组件', '权限', '岗位', '告知'],
#  ['组件', '权限', '岗位', '告知'],
#  ['组件', '权限', '岗位', '告知'],
#  ['组件', '权限', '岗位', '告知'],
#  ['权限', '查询'],
#  ['权限', '查询'],
#  ['权限', '查询'],
#  ['权限', '查询'],
#  ['权限', '查询'],
#  ['权限', '查询'],
#  ['Portal', '账号', '查询', '不能'],
#  ['Portal', '账号', '查询', '不能'],
#  ['Portal', '账号', '查询', '不能'],
#  ['Portal', '账号', '查询', '不能'],
#  ['Portal', '账号', '查询', '不能'],
#  ['Portal', '账号', '查询', '不能'],
#  ['Portal', '账号', '流程', '申请'],
#  ['Portal', '账号', '流程', '申请'],
#  ['Portal', '账号', '流程', '申请'],
#  ['Portal', '账号', '流程', '申请'],
#  ['Portal', '账号', '流程', '申请'],
#  ['Portal', '登录', '密码', '不能'],
#  ['Portal', '登录', '密码', '不能'],
#  ['Portal', '输错', '30', '急用', '登录'],
#  ['Portal', '输错', '30', '急用', '登录'],
#  ['Portal', '输错', '30', '急用', '登录'],
#  ['Portal', '输错', '30', '急用', '登录'],
#  ['Portal', '输错', '30', '急用', '登录'],
#  ['Portal', '输错', '30', '急用', '登录'],
#  ['Portal', '管理部', '账号', '流程', '申请'],
#  ['Portal', '管理部', '账号', '流程', '申请'],
#  ['新员工', 'portal', '账号', '密码', '创建'],
#  ['新员工', 'portal', '账号', '密码', '创建'],
#  ['新员工', 'portal', '账号', '密码', '创建'],
#  ['CDNW', 'Portal', 'PMS', '工单', '账号'],
#  ['CDNW', 'Portal', 'PMS', '工单', '账号'],
#  ['CDNW', 'Portal', 'PMS', '工单', '账号'],
#  ['CDNW', 'Portal', 'PMS', '工单', '账号'],
#  ['CDNW', 'Portal', 'PMS', '工单', '账号'],
#  ['CDNW', 'Portal', 'PMS', '工单', '账号'],
#  ['登录', '非法', '提示', '位置', '解决'],
#  ['登录', '非法', '提示', '位置', '解决'],
#  ['登录', '非法', '提示', '位置', '解决'],
#  ['登录', '非法', '提示', '位置', '解决'],
#  ['Portal', '账号', '批量', '创建'],
#  ['Portal', '账号', '批量', '创建'],
#  ['Portal', '账号', '批量', '创建'],
#  ['Portal', '账号', '批量', '创建'],
#  ['Portal', '账号', '批量', '创建'],
#  ['申请', 'Portal', '账号', '流程', '客户'],
#  ['申请', 'Portal', '账号', '流程', '客户'],
#  ['Portal', '账号', '共用', '申请'],
#  ['Portal', '账号', '共用', '申请'],
#  ['Portal', '账号', '共用', '申请'],
#  ['35', '账号', '申请', '特殊'],
#  ['35', '账号', '申请', '特殊'],
#  ['35', '账号', '申请', '特殊'],
#  ['35', '账号', '申请', '特殊'],
#  ['35', '账号', '申请', '特殊'],
#  ['PMS', '测试环境', '账号', '流程', '申请'],
#  ['PMS', '测试环境', '账号', '流程', '申请'],
#  ['PMS', '测试环境', '账号', '流程', '申请'],
#  ['PMS', '测试环境', '账号', '流程', '申请'],
#  ['PMS', '测试环境', '账号', '流程', '申请'],
#  ['外网', '测试环境', '账号', '申请'],
#  ['外网', '测试环境', '账号', '申请'],
#  ['外网', '测试环境', '账号', '申请'],
#  ['外网', '测试环境', '账号', '申请'],
#  ['外网', '测试环境', '账号', '申请'],
#  ['Portal', '测试环境', 'IP', '登录', '限制'],
#  ['Portal', '测试环境', 'IP', '登录', '限制'],
#  ['Portal', '测试环境', 'IP', '登录', '限制'],
#  ['Portal', '测试环境', 'IP', '登录', '限制'],
#  ['Portal', '测试环境', 'IP', '登录', '限制'],
#  ['Portal', '测试环境', 'IP', '登录', '限制'],
#  ['Portal', '测试环境', 'IP', '登录', '限制'],
#  ['Portal', '测试环境', 'IP', '登录', '限制'],
#  ['Portal', '测试环境', 'IP', '登录', '限制'],
#  ['Portal', '测试环境', 'IP', '登录', '限制'],
#  ['Portal', '测试环境', 'IP', '登录', '限制'],
#  ['流程', '新增', '资源', '数据'],
#  ['流程', '新增', '资源', '数据'],
#  ['流程', '新增', '资源', '数据'],
#  ['流程', '新增', '资源', '数据'],
#  ['流程', '新增', '资源', '数据'],
#  ['流程', '新增', '资源', '数据'],
#  ['流程', '新增', '资源', '数据'],
#  ['流程', '新增', '资源', '数据'],
#  ['流程', '新增', '资源', '数据'],
#  ['流程', '新增', '资源', '数据'],
#  ['MAA', '权限', 'portal', '客户名单', '看不到'],
#  ['MAA', '权限', 'portal', '客户名单', '看不到'],
#  ['MAA', '权限', 'portal', '客户名单', '看不到'],
#  ['MAA', '权限', 'portal', '客户名单', '看不到'],
#  ['MAA', '权限', 'portal', '客户名单', '看不到'],
#  ['MAA', '权限', 'portal', '客户名单', '看不到'],
#  ['MAA', '权限', 'portal', '客户名单', '看不到'],
#  ['MAA', '权限', 'portal', '客户名单', '看不到'],
#  ['MAA', '权限', 'portal', '客户名单', '看不到'],
#  ['MAA', '权限', 'portal', '客户名单', '看不到'],
#  ['MAA', '权限', 'portal', '客户名单', '看不到'],
#  ['MAA', '权限', 'portal', '客户名单', '看不到'],
#  ['Cas', '权限', '登录', '申请'],
#  ['Cas', '权限', '登录', '申请'],
#  ['Cas', '权限', '登录', '申请'],
#  ['Cas', '权限', '登录', '申请'],
#  ['Cas', '权限', '登录', '申请'],
#  ['管理员', '组件', '权限', '申请'],
#  ['管理员', '组件', '权限', '申请'],
#  ['管理员', '组件', '权限', '申请'],
#  ['NMP', '权限', '登录', '申请'],
#  ['NMP', '权限', '登录', '申请'],
#  ['NMP', '权限', '登录', '申请'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['工单', '账号', 'PMS', '批量', '权限'],
#  ['工单', '账号', 'PMS', '批量', '权限'],
#  ['工单', '账号', 'PMS', '批量', '权限'],
#  ['工单', '找不到', '填写', '岗位'],
#  ['工单', '找不到', '填写', '岗位'],
#  ['下一步', 'PMS', '工单', '组件', '流转'],
#  ['下一步', 'PMS', '工单', '组件', '流转'],
#  ['下一步', 'PMS', '工单', '组件', '流转'],
#  ['PMS', 'Portal', '组件', '账号', '权限'],
#  ['PMS', 'Portal', '组件', '账号', '权限'],
#  ['Portal', '工单', '审核'],
#  ['Portal', '工单', '审核'],
#  ['入职', 'PMS', 'Portal', '找不到', '下一步'],
#  ['入职', 'PMS', 'Portal', '找不到', '下一步'],
#  ['入职', 'PMS', 'Portal', '找不到', '下一步'],
#  ['流程', '审批'],
#  ['流程', '审批'],
#  ['流程', '审批'],
#  ['流程', '审批'],
#  ['流程', '审批'],
#  ['Portal', '菜单', '入口', '修改', '名称'],
#  ['Portal', '菜单', '入口', '修改', '名称'],
#  ['Portal', '菜单', '入口', '修改', '名称'],
#  ['Portal', '菜单', '入口', '修改', '名称'],
#  ['一级菜单', '菜单', '权限', '顶级', '修改'],
#  ['一级菜单', '菜单', '权限', '顶级', '修改'],
#  ['一级菜单', '菜单', '权限', '顶级', '修改'],
#  ['一级菜单', '菜单', '权限', '顶级', '修改'],
#  ['功能码', '申请'],
#  ['功能码', '申请'],
#  ['功能码', '申请'],
#  ['走流程', '菜单', '移动', '位置'],
#  ['走流程', '菜单', '移动', '位置'],
#  ['新组件', '上线', '流程'],
#  ['新组件', '上线', '流程'],
#  ['新组件', '上线', '流程'],
#  ['Portal', '找不到', '组件', '名称'],
#  ['Portal', '找不到', '组件', '名称'],
#  ['Portal', '找不到', '组件', '名称'],
#  ['Portal', '找不到', '组件', '名称'],
#  ['Portal', '找不到', '组件', '名称'],
#  ['走流程', '角色', '新增'],
#  ['走流程', '角色', '新增'],
#  ['走流程', '角色', '新增'],
#  ['走流程', '组件', '新增', '功能', '产品'],
#  ['走流程', '组件', '新增', '功能', '产品'],
#  ['走流程', '组件', '新增', '功能', '产品'],
#  ['账号', '查询', '关联', '角色'],
#  ['账号', '查询', '关联', '角色'],
#  ['找谁', '线上', '新增', '申请', '应用'],
#  ['找谁', '线上', '新增', '申请', '应用'],
#  ['子菜单', '权限', '申请', '特殊', '管理'],
#  ['子菜单', '权限', '申请', '特殊', '管理'],
#  ['子菜单', '权限', '申请', '特殊', '管理'],
#  ['工单', '组件', '填写', '权限', '变更'],
#  ['工单', '组件', '填写', '权限', '变更'],
#  ['工单', '组件', '填写', '权限', '变更'],
#  ['账号', '查询', '岗位', '关联', '名称'],
#  ['账号', '查询', '岗位', '关联', '名称'],
#  ['账号', '查询', '岗位', '关联', '名称'],
#  ['岗位', '代码', '命名', '规范', '名称'],
#  ['岗位', '代码', '命名', '规范', '名称'],
#  ['岗位', '代码', '命名', '规范', '名称'],
#  ['岗位', '代码', '命名', '规范', '名称'],
#  ['wiki', '流程', '申请', '空间'],
#  ['wiki', '流程', '申请', '空间'],
#  ['wiki', '流程', '申请', '空间'],
#  ['wiki', '流程', '申请', '空间'],
#  ['Confluence', '教程', '查看'],
#  ['Confluence', '教程', '查看'],
#  ['Confluence', '教程', '查看'],
#  ['Confluence', '教程', '查看'],
#  ['Confluence', '教程', '查看'],
#  ['Confluence', '教程', '查看'],
#  ['Confluence', '教程', '查看'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['Wiki', '权限', '流程', '开通', '访问'],
#  ['Wiki', '权限', '流程', '开通', '访问'],
#  ['Wiki', '权限', '流程', '开通', '访问'],
#  ['Wiki', '权限', '流程', '开通', '访问'],
#  ['Wiki', '权限', '流程', '开通', '访问'],
#  ['Wiki', '权限', '流程', '开通', '访问'],
#  ['Wiki', '权限', '流程', '开通', '访问'],
#  ['Wiki', '权限', '流程', '开通', '访问'],
#  ['Wiki', '权限', '流程', '开通', '访问'],
#  ['Wiki', '权限', '流程', '开通', '访问'],
#  ['Wiki', '权限', '流程', '开通', '访问'],
#  ['wiki地址', '打不开'],
#  ['wiki地址', '打不开'],
#  ['wiki地址', '打不开'],
#  ['wiki地址', '打不开'],
#  ['wiki地址', '打不开'],
#  ['wiki地址', '打不开'],
#  ['PMS', '找谁', '咨询', '问题'],
#  ['PMS', '找谁', '咨询', '问题'],
#  ['PMS', '找谁', '咨询', '问题'],
#  ['PMS', '找谁', '咨询', '问题'],
#  ['SI', '账号密码', 'Portal', '账户', '系统'],
#  ['SI', '账号密码', 'Portal', '账户', '系统'],
#  ['35', '账号', '流程', '申请'],
#  ['35', '账号', '流程', '申请'],
#  ['35', '账号', '流程', '申请'],
#  ['35', '账号', '流程', '申请'],
#  ['35', '权限', '流程', '申请'],
#  ['35', '权限', '流程', '申请'],
#  ['35', '权限', '流程', '申请'],
#  ['35', '权限', '流程', '申请'],
#  ['找谁', '重置', '密码', '开通', '系统'],
#  ['找谁', '重置', '密码', '开通', '系统'],
#  ['找谁', '重置', '密码', '开通', '系统'],
#  ['网宿', '白名单', 'PMS', '账号', '流程'],
#  ['网宿', '白名单', 'PMS', '账号', '流程'],
#  ['网宿', '白名单', 'PMS', '账号', '流程'],
#  ['网宿', '白名单', 'PMS', '账号', '流程'],
#  ['网宿', '白名单', 'PMS', '账号', '流程'],
#  ['网宿', '白名单', 'PMS', '账号', '流程'],
#  ['Task', '找谁', '权限', '不够'],
#  ['Task', '找谁', '权限', '不够'],
#  ['Task', '找谁', '权限', '不够'],
#  ['Task', '找谁', '权限', '不够'],
#  ['Task', '账号', '流程', '申请'],
#  ['Task', '账号', '流程', '申请'],
#  ['Task', '账号', '流程', '申请'],
#  ['Task', '账号', '流程', '申请'],
#  ['Task', '账号', '流程', '申请'],
#  ['Task', '账号', '流程', '申请'],
#  ['Task', '密码', '忘记'],
#  ['Task', '密码', '忘记'],
#  ['Task', '密码', '忘记'],
#  ['Portal', '找谁', '导出', '需求', '数据'],
#  ['Portal', '找谁', '导出', '需求', '数据'],
#  ['云平台', '手机号', '占用', '注册', '发现'],
#  ['云平台', '手机号', '占用', '注册', '发现'],
#  ['权限', '生效'],
#  ['权限', '生效'],
#  ['权限', '生效'],
#  ['403', '菜单', '权限', '开通', '查看'],
#  ['403', '菜单', '权限', '开通', '查看'],
#  ['菜单', '权限', '看不到', '开通'],
#  ['菜单', '权限', '看不到', '开通'],
#  ['权限', '额外', '流程', '申请', '销售'],
#  ['权限', '额外', '流程', '申请', '销售'],
#  ['权限', '额外', '流程', '申请', '销售'],
#  ['权限', '额外', '流程', '申请', '销售'],
#  ['权限', '额外', '流程', '申请', '销售'],
#  ['轮岗', '权限', '员工', '申请'],
#  ['部门', '权限', '添加', '转到'],
#  ['转岗', '权限', '岗位', '开通'],
#  ['运维部', '权限', '转到', '申请'],
#  ['岗位变动', '权限', '申请'],
#  ['岗位', '流程', '新增'],
#  ['岗位', '流程', '变更', '已有'],
#  ['scmtg', '组件', '权限', '流程', '申请'],
#  ['gpc', 'db', '组件', '权限', '流程'],
#  ['acpui', '组件', '权限', '流程', '申请'],
#  ['eagle', '组件', '权限', '流程', '申请'],
#  ['conf', '组件', '权限', '流程', '申请'],
#  ['SMART', '组件', '权限', '流程', '申请'],
#  ['ngb', 'dm', '组件', '权限', '流程'],
#  ['DNA', '控制台', '权限', '流程', '开通'],
#  ['scm', '组件', '权限', '流程', '申请'],
#  ['dc', 'display', '组件', '权限', '流程'],
#  ['ngb', 'display', 'agent', 'http', 'datacenter'],
#  ['dc', 'collect', '组件', '权限', '流程'],
#  ['CI', '权限', '申请'],
#  ['CustomerInsight', '权限', '申请'],
#  ['CCM', '权限', '流程', '申请'],
#  ['dna', 'console', '权限', '流程', '开通'],
#  ['dc', 'user', '权限', '流程', '开通'],
#  ['DNA', 'user', '权限', '流程', '开通'],
#  ['申请', 'Portal', 'RCT', '运维', 'rct'],
#  ['gdui', '组件', '权限', '流程', '申请'],
#  ['ServiceInsight', '权限', '流程', '申请'],
#  ['SI', '权限', '申请'],
#  ['SI', '权限', '申请'],
#  ['申请', 'SI', '权限'],
#  ['protal', '流程', '关联', '角色'],
#  ['岗位', '角色', '划分', '申请', '部门'],
#  ['portal', '权限', '开通'],
#  ['portal', '菜单', '权限', '开通'],
#  ['portal', '权限', '查询', '开通', '信息'],
#  [],
#  ['Hello'],
#  ['管理员', '组件'],
#  ['TASK', '管理员', '组件'],
#  ['PMS', '管理员', '组件'],
#  ['组件', '查询', '岗位', '协助', '管理'],
#  ['组件', '岗位', '管理', '使用', '进行'],
#  ['权限', '岗位', '角色', '不能'],
#  ['权限', '岗位', '角色'],
#  ['权限', '岗位', '角色'],
#  ['组件', '权限', '岗位'],
#  ['申请', '组件', '权限', '岗位'],
#  ['组件', '权限', '岗位'],
#  ['组件', '权限', '岗位', '告知', '适合'],
#  ['组件', '权限', '岗位', '获取', '进行'],
#  ['权限'],
#  ['查下', '权限'],
#  ['看下', '权限'],
#  ['权限'],
#  ['看下', '权限', '查询'],
#  ['权限'],
#  ['岗位'],
#  ['权限', '岗位', '申请'],
#  ['portal', '账号', '密码', '忘记'],
#  ['portal', '账号', '忘记'],
#  ['账号', '验证'],
#  ['没反应', '挂了'],
#  ['Portal', '权限', '流程', '申请'],
#  ['portal', '权限', '申请'],
#  ['portal', '权限', '流程', '申请'],
#  ['portal', '权限', '申请'],
#  ['portal', '权限', '开通'],
#  ['Portal', '账号', '密码', '修改'],
#  ['portal', '登录不了'],
#  ['Portal', '输错', '解锁', '密码'],
#  ['portal', '输错', '30', '急用', '登录'],
#  ['portal', '输错', '被锁', '急用', '密码'],
#  ['portal', '输错', '被锁', '急用', '密码'],
#  ['等待时间', 'portal', '有误', '登录', '密码'],
#  ['portal', '出错', '登录', '密码', '一直'],
#  ['Portal', '管理部', '权限', '流程', '申请'],
#  ['portal', '管理部', '账号', '申请', '设备'],
#  ['Portal', '账号', '开通'],
#  ['Portal', '账号', '申请'],
#  ['portal', '账号', '线上', '申请', '环境'],
#  ['CDNW', 'portal', '用工', '账号', '客服'],
#  ['PMS', '工单', 'CDNW', 'portal', '账号'],
#  ['CDNW', 'portal', 'PMS', '工单', '账号'],
#  ['CDNW', 'Portal', '账号', '客服', '开通'],
#  ['CDNW', 'pms', '账号', '客服', '开通'],
#  ['CDNW', 'Portal', '账号', '客服', '申请'],
#  ['登录', '电脑', '非法', '位置'],
#  ['登录', '非法', '位置'],
#  ['笔芯', '登录', '非法', '位置', '解决'],
#  ['登录', '非法', '位置', '解决'],
#  ['portal', '账号', '批量', '创建'],
#  ['portal', '账号', '批量', '创建'],
#  ['portal', '账号', '批量', '申请'],
#  ['portal', '账号', '创建', '多个'],
#  ['portal', '账号', '批量', '问题'],
#  ['权限', '添加', '客户'],
#  ['走流程', '权限', '角色', '客户', '新增'],
#  ['Portal', '账号', '公共', '申请'],
#  ['portal', '走流程', '账号', '共用', '申请'],
#  ['portal', '账号', '公共', '申请'],
#  ['35', '权限', '申请', '特殊'],
#  ['35', '走流程', '账号'],
#  ['35', '账号', '申请', '特殊'],
#  ['35', '找谁', '账号', '流程', '申请'],
#  ['35', '账号', '特殊', '问题'],
#  ['pms', '账号', '测试', '申请'],
#  ['pms', '账号', '开通', '测试'],
#  ['PMS', '测试环境', '账号', '申请'],
#  ['PMS', '测试环境', '找谁', '账号', '开通'],
#  ['PMS', '测试环境', '账号', '登录', '开通'],
#  ['内网', '测试环境', '权限', '申请'],
#  ['内网', '测试环境', 'portal', '账号', '申请'],
#  ['公网', '测试环境', '权限', '开通'],
#  ['测试环境', '账号', '申请'],
#  ['测试环境', '权限', '申请'],
#  ['portal', '测试环境', '登录不了', 'IP', '限制'],
#  ['portal', '测试环境', 'IP', '限制'],
#  ['portal', '测试环境', 'IP', '登录', '限制'],
#  ['portal', 'ip', '登录', '限制'],
#  ['Portal', '测试环境', 'IP', '登陆', '限制'],
#  ['Portal', '测试环境', 'IP', '登陆', '限制'],
#  ['Portal', '测试环境', 'IP', '登陆', '限制'],
#  ['Portal', '测试环境', 'IP', '不上', '登陆'],
#  ['IP', '不上', 'Portal', '测试环境', '登陆'],
#  ['登录不上', 'Portal', '测试环境', 'IP', '限制'],
#  ['IP', '登录不上', 'Portal', '测试环境', '限制'],
#  ['流程', '新增', '资源', '数据'],
#  ['流程', '新增', '资源', '数据'],
#  ['流程', '新增', '资源', '数据'],
#  ['流程', '新增', '具体', '资源', '数据'],
#  ['添加', '流程', '资源', '数据'],
#  ['流程', '新增', '资源', '数据'],
#  ['流程', '新增', '资源', '数据'],
#  ['数组', '添加', '流程', '资源'],
#  ['新增', '资源', '数据'],
#  ['新增', '资源', '数据'],
#  ['MAA', 'portal', '客户名单', '权限', '看不到'],
#  ['MAA', 'portal', '客户名单', '权限', '看不到'],
#  ['MAA', 'portal', '客户名单', '权限', '查看'],
#  ['MAA', 'portal', '客户名单', '权限', '看不到'],
#  ['MAA', 'portal', '客户名单', '权限', '看不到'],
#  ['portal', 'MAA', '客户名单'],
#  ['portal', 'MAA', '客户名单', '权限', '查看'],
#  ['MAA', '客户名单', '权限', '申请'],
#  ['MAA', '客户名单', '权限', '看不到', '已有'],
#  ['MAA', '查下', '客户名单', '权限', '看不到'],
#  ['MAA', '客户名单'],
#  ['MAA', '客户名单', '关联'],
#  ['portal', 'CloudDNS', 'pms', '填写', '开通'],
#  ['portal', 'CloudDNS', '账号', '流程', '开通'],
#  ['dns', 'quansucloud', 'com', '权限', '地址'],
#  ['云cas', 'DNS', '有误', '权限', '解析'],
#  ['全速云', '权限', '申请'],
#  ['域名', '别名', '权限', '添加', '申请'],
#  ['域名', '别名', '权限', '修改', '申请'],
#  ['域名', '别名', '权限', '申请', '配置'],
#  ['NMP', '权限', '登录', '申请'],
#  ['NMP', '权限', '登录', '申请'],
#  ['NMP', '权限', '登录', '申请'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['CDN', 'API', '文档', '权限', '查看'],
#  ['CDN', 'API', '文档', '权限', '查看'],
#  ['CDN', 'API', '文档', '查看', '通用'],
#  ['CDN', 'API', '文档', '权限', '查看'],
#  ['通用岗位', 'CDN', 'API', '文档', '权限'],
#  ['PMS', '工单', '账号', '权限', '关联'],
#  ['pms', '工单', '账号', '批量', '输入'],
#  ['账号', '关联', '工单', '权限', '发起'],
#  ['工单', '找不到', '填写', '角色'],
#  ['工单', '找不到', '组件', '填写'],
#  ['PMS', '工单', '下一步', '不存在', '流转'],
#  ['PMS', '工单', '下一步', '流转'],
#  ['PMS', '工单', '某一步', '下一步', '找谁'],
#  ['PMS', '组件', '离职', '流程', '更新'],
#  ['PMS', '组件', '有误', '接口', '名单'],
#  ['组件', '权限', '岗位', '通知', '申请'],
#  ['portal', '工单', '审核'],
#  ['portal', '找不到', '下一步', '权限', '申请'],
#  ['新员工', 'portal', '下一步', '权限', '申请'],
#  ['PMS', '走流程', 'Portal', '下一步', '权限'],
#  ['工单'],
#  ['工单'],
#  ['工单', '审批'],
#  ['工单', '审核'],
#  ['流程', '审核'],
#  ['portal', '菜单', '入口', '修改', '名称'],
#  ['portal', '菜单', '入口', '名称'],
#  ['portal', '菜单名', '入口', '修改'],
#  ['菜单', '顶级', '修改', '名称'],
#  ['层级', '菜单', '修改'],
#  ['一级菜单', '菜单', '顶级', '改为'],
#  ['一级菜单', '提为', '菜单', '顶级'],
#  ['一级菜单', '菜单', '权限', '顶级', '修改'],
#  ['功能码', '申请'],
#  ['功能码', '申请'],
#  ['功能码', '流程', '申请'],
#  ['菜单', '顺序', '调整'],
#  ['功能码', '走流程', '移动', '位置'],
#  ['组件', '流程', '新增', '申请'],
#  ['新组件', 'portal', '走流程', '权限', '接入'],
#  ['组件', '申请'],
#  ['portal', '找不到', '组件'],
#  ['portal', '找不到', '组件'],
#  ['portal', '找不到', '组件'],
#  ['portal', '找不到', '组件', '原因'],
#  ['portal', '组件', '找到'],
#  ['走流程', '菜单', '添加', '角色', '客户'],
#  ['PMS', '工单', '组件', '权限', '入口'],
#  ['找不到', '工单', '走流程', '菜单', '组件'],
#  ['组件', '接口', '权限', '更好', '新增'],
#  ['组件', '流程', '新增', '功能', '产品'],
#  ['流程', '新增', '功能', '产品'],
#  ['账号', '查询', '关联', '角色'],
#  ['账号', '查询', '关联', '角色'],
#  ['找谁', '线上', '新增', '申请', '资源'],
#  ['申请', 'Portal', '应用'],
#  ['子菜单', '部分'],
#  ['子菜单', '权限', '特殊', '增加'],
#  ['菜单', '部署'],
#  ['工单', '组件', '权限', '变更', '只能'],
#  ['组件', '权限', '变更', '多个'],
#  ['工单', '组件', '权限', '变更'],
#  ['岗位'],
#  ['关联关系', '账号', '查询', '岗位'],
#  ['账号', '查询', '岗位', '关联'],
#  ['岗位', '代码', '命名', '规范', '名称'],
#  ['岗位', '代码', '命名', '规范', '名称'],
#  ['岗位', '代码', '命名', '规范', '名称'],
#  ['岗位', '代码', '命名', '规范', '名称'],
#  ['WIKI', '流程', '申请', '空间'],
#  ['wiki', '申请', '空间'],
#  ['wiki', '申请', '空间'],
#  ['wiki', '流程', '开通', '空间'],
#  ['Confluence', '使用'],
#  ['Confluence', '教程'],
#  ['Confluence', '不会'],
#  ['Confluence', '教程'],
#  ['Confluence', '教程', '查看'],
#  ['Confluence', '教程'],
#  ['Confluence', '教程'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '流程', '申请'],
#  ['WIKI', '账号', '申请'],
#  ['WIKI', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '开通'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请', '公司'],
#  ['confluence', 'wiki', '申请'],
#  ['confluence', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '获取'],
#  ['wiki', '找谁', '账号', '公司'],
#  ['wiki', '找谁', '账号'],
#  ['wiki', '账号', '注册'],
#  ['申请', 'wiki', '账号'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '账号', '申请'],
#  ['wiki', '清楚点', '账号', '投诉', '注册'],
#  ['WIKI', '权限', '访问'],
#  ['WIKI', '权限', '开通', '访问'],
#  ['wiki', '权限', '开通', '访问'],
#  ['wiki', '找谁', '权限', '开通', '访问'],
#  ['Wiki', '权限', '开通', '访问'],
#  ['Wiki', '权限', '流程', '开通', '访问'],
#  ['Wiki', '文档', '权限', '开通', '访问'],
#  ['Wiki', '权限', '开通', '访问'],
#  ['wiki', '权限', '开通', '访问'],
#  ['wiki', '权限', '开通', '访问'],
#  ['wiki', '找谁', '权限', '开通'],
#  ['WIKI', '打不开', '地址'],
#  ['WIKI', '打不开', '地址', '原因'],
#  ['confluence', '打不开'],
#  ['wiki地址', '打不开'],
#  ['wiki地址', '打不开', '解决', '原因'],
#  ['几点'],
#  ['pms', '问题'],
#  ['pms', '找谁', '问题'],
#  ['pms', '咨询', '问题'],
#  ['pms', '负责人'],
#  ['SI', 'portal', '账号', '登录'],
#  ['portal', 'si', '账号', '登录'],
#  ['35', '申请'],
#  ['35', '找谁', '账号', '申请'],
#  ['35', '账号', '开通'],
#  ['35', '申请', '说明'],
#  ['35', '密码'],
#  ['35', '账号', '权限', '申请'],
#  ['35', '账号', '权限', '申请'],
#  ['35', '账号', '权限', '流程', '申请'],
#  ['重置', '密码', '开通', '系统'],
#  ['重置', '密码', '开通', '系统'],
#  ['找谁', '重置', '密码', '开通', '系统'],
#  ['网宿', '白名单', '账号', '配置', '内部'],
#  ['白名单', '账号', '配置', '内部'],
#  ['白名单', '走流程', '账号', '配置', '内部'],
#  ['白名单', '账号', '配置', '内部'],
#  ['白名单', '找谁', '账号', '配置', '内部'],
#  ['白名单', '账号', '配置', '内部'],
#  ['portal', '权限', '申请'],
#  ['TASK', '找谁', '权限', '流水', '开通'],
#  ['TASK', '找谁', '服务器', '授权', '进行'],
#  ['TASK', '服务器', '权限', '授权'],
#  ['task', '账号', '开通'],
#  ['task', '账号', '拥有'],
#  ['找谁', 'task', '账号', '开通'],
#  ['task', '账号', '申请'],
#  ['task', '能发', '账号', '流程', '申请'],
#  ['task', '账号', '申请'],
#  ['Task', '密码', '忘记'],
#  ['Task', '找回', '密码'],
#  ['Task', '找回', '密码'],
#  ['portal', '导出', '数据'],
#  ['portal', '导出', '流程', '数据'],
#  ['云平台', '手机号', '占用', '注册', '提示'],
#  ['全速云', '占用', '注册', '手机'],
#  ['权限', '生效'],
#  ['权限', '生效', '多久'],
#  ['工单', '权限', '生效', '多久', '结束'],
#  ['403', '菜单', '权限', '查看', '完毕'],
#  ['权限', '开通', '多久'],
#  ['入口', '找不到', '菜单', '权限', '配置'],
#  ['菜单', '权限', '入口', '看不到', '开通'],
#  ['售前', '权限', '额外', '流程', '申请'],
#  ['权限', '额外', '申请', '销售'],
#  ['权限', '额外', '流程', '申请', '销售'],
#  ['权限', '额外', '申请', '销售'],
#  ['权限', '额外', '申请', '销售']]

# %% [markdown]
# # Prepare Dataset

# %%
write_path = open('../dataset/train.txt', 'w', encoding='utf-8')

# %%
with open('statistic_original_without_stopwords.txt', 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip('\n')
        for word in line.split(' '):
            if '/' in word:
                chars = [c for c in word.split('/')[0]]
                write_path.write(chars[0] + ' B-IPT\n')
                if len(chars) > 1:
                    for i in range(1, len(chars)):
                        write_path.write(chars[i] + ' I-IPT\n')
            else:
                chars = [c for c in word]
                for i in range(len(chars)):
                    write_path.write(chars[i] + ' O\n')
        write_path.write('\n')
print('Done!')
# Out:
# Done!
